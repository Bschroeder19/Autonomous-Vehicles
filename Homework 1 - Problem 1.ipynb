# %%
import numpy

# %%
from matplotlib import pyplot as plt

# %%
import cv2

# %%
img = cv2.imread(r'/Users/oliviakeils/Desktop/ME5950 - Autonomous Vehicles/AUTO.png')

# %%
plt.imshow(img)

# %%
print(img.shape)
# Out:
# (764, 1327, 3)

# %%
# Above shows the ratio of colors in terms of BGR
# The picture has a majority of Blue and Green pigments which is seen above

# %%
conda install pip
# Out:
# ...
# Solving environment: done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install opencv-contrib-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY) 
gray = cv2.medianBlur(gray, 7) 
edges = cv2.adaptiveThreshold(gray, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, 9, 10)

# %%
plt.imshow(gray)

# %%
# Reviewed different commands to help locate the edges of the photo

# %%
cartoon = cv2.bitwise_and(color, color, mask=edges)

# %%
plt.imshow(cartoon)

# %%
edge = cv2.Canny(img,100,200)

# %%
plt.imshow(edge)
