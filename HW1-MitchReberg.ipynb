# %%
import pandas as pd
df = pd.read_excel(r'C:\Users\16165\Desktop\ME 5950 - Auto Automobiles\Lab0_data.xlsx')

# %%
print(df)
# Out:
#      time_sec  VehicleSpeed_mph  EngineSpeed_rpm  EngineTorque  AccelPedalPos  \
# 0           0         23.838108      2321.373607    181.943925      19.978017
# 1           1         25.183644      1888.784906     63.500000      12.549024
# 2           2         25.592899      1932.336262     46.942052       5.007143
# 3           3         25.483396      1398.949090     -8.576612       0.000000
# 4           4         24.904355      1379.242030    -19.000000       0.000000
# ..        ...               ...              ...           ...            ...
# 826       826         15.377161      2109.273816     63.692830       9.019611
# 827       827         16.387776      1562.750000     38.330566       7.843140
# 828       828         16.879580      1607.067105     38.165314       7.450983
# 829       829         17.458570      1670.917720     71.562284      16.332432
# 830       830         19.819313      2010.301629    134.000000      19.607850
#
# ...

# %%
df.columns
# Out:
# Index(['time_sec', 'VehicleSpeed_mph', 'EngineSpeed_rpm', 'EngineTorque',
#        'AccelPedalPos', 'BrakePedalPos', 'TurnSignal', 'Latitude_deg',
#        'Longitude_deg', 'Altitude', 'Distance', 'SteerAngle',
#        'TransmissionGear', 'SPaT_signal', 'SPaT_dist'],
#       dtype='object')

# %%
column_subset = [
    "time_sec" ,
    "VehicleSpeed_mph" ,
    "EngineSpeed_rpm" ,
    "EngineTorque" ,
    "AccelPedalPos" ,
    "BrakePedalPos" ,
    "TurnSignal" ,
    "Latitude_deg" ,
    "Longitude_deg" ,
    "Altitude", 
    "Distance" ,
    "SteerAngle" ,
    "TransmissionGear" ,
    "SPaT_signal",
    "SPaT_dist"
]

# %%
sorted(column_subset)
# Out:
# ['AccelPedalPos',
#  'Altitude',
#  'BrakePedalPos',
#  'Distance',
#  'EngineSpeed_rpm',
#  'EngineTorque',
#  'Latitude_deg',
#  'Longitude_deg',
#  'SPaT_dist',
#  'SPaT_signal',
#  'SteerAngle',
#  'TransmissionGear',
#  'TurnSignal',
#  'VehicleSpeed_mph',
#  'time_sec']

# %%
## With the sorted data we can graph them alphabetically for viewing pleasure.

# %%
df2=pd.read_excel(r'C:\Users\16165\Desktop\ME 5950 - Auto Automobiles\Lab0_data.xlsx',
usecols=(column_subset),
nrows=831
                )

# %%
print(df2)
# Out:
#      VehicleSpeed_mph  EngineSpeed_rpm  EngineTorque  AccelPedalPos  \
# 0           23.838108      2321.373607    181.943925      19.978017
# 1           25.183644      1888.784906     63.500000      12.549024
# 2           25.592899      1932.336262     46.942052       5.007143
# 3           25.483396      1398.949090     -8.576612       0.000000
# 4           24.904355      1379.242030    -19.000000       0.000000
# ..                ...              ...           ...            ...
# 826         15.377161      2109.273816     63.692830       9.019611
# 827         16.387776      1562.750000     38.330566       7.843140
# 828         16.879580      1607.067105     38.165314       7.450983
# 829         17.458570      1670.917720     71.562284      16.332432
# 830         19.819313      2010.301629    134.000000      19.607850
#
#      BrakePedalPos  TurnSignal  Latitude_deg  Longitude_deg     Altitude  \
# 0              0.0         0.0     40.581519    -105.077463  150756.7639
# ...

# %%
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
plt.ylabel('Accel Pedal Pos')
plt.xlabel('Time (s)')
plt.title('Gas Pedal Position vs Time')
plt.plot(df['AccelPedalPos'])
plt.show()

# %%
df['AccelPedalPos']
# Out:
# 0      19.978017
# 1      12.549024
# 2       5.007143
# 3       0.000000
# 4       0.000000
#          ...
# 826     9.019611
# 827     7.843140
# 828     7.450983
# 829    16.332432
# 830    19.607850
# Name: AccelPedalPos, Length: 831, dtype: float64

# %%
## I did this to verify and see if the data was actually graphing in the correct value range

# %%
plt.ylabel('Altitude')
plt.xlabel('Time (s)')
plt.title('Altitude vs Time')
plt.plot(df['Altitude'])
plt.show()

# %%
plt.ylabel('Brake Pedal Pos')
plt.xlabel('Time (s)')
plt.title('Brake Pedal Position vs Time')
plt.plot(df['BrakePedalPos'])
plt.show()

# %%
plt.ylabel('Distance')
plt.xlabel('Time (s)')
plt.title('Distance vs Time')
plt.plot(df['Distance'])
plt.show()

# %%
plt.ylabel('EngineSpeed (rpm)')
plt.xlabel('Time (s)')
plt.title('Engine Speed vs Time')
plt.plot(df['EngineSpeed_rpm'])
plt.show()

# %%
plt.ylabel('EngineTorque')
plt.xlabel('Time (s)')
plt.title('Engine Torque vs Time')
plt.plot(df['EngineTorque'])
plt.show()

# %%
plt.ylabel('Latitude (deg)')
plt.xlabel('Time (s)')
plt.title('Latitude vs Time')
plt.plot(df['Latitude_deg'])
plt.show()

# %%
plt.ylabel('Longitude (deg)')
plt.xlabel('Time (s)')
plt.title('Longitude vs Time')
plt.plot(df['Longitude_deg'])
plt.show()

# %%
plt.ylabel('SPaT (dist)')
plt.xlabel('Time (s)')
plt.title('SPaT vs Time')
plt.plot(df['SPaT_dist'])
plt.show()

# %%
plt.ylabel('SPaT Signal')
plt.xlabel('Time (s)')
plt.title('Spat Signal vs Time')
plt.plot(df['SPaT_signal'])
plt.show()

# %%
plt.ylabel('Steer Angle')
plt.xlabel('Time (s)')
plt.title('Steering Angle vs Time')
plt.plot(df['SteerAngle'])
plt.show()

# %%
plt.ylabel('Transmission (Gear Number)')
plt.xlabel('Time (s)')
plt.title('Transmission Gear vs Time')
plt.plot(df['TransmissionGear'])
plt.show()

# %%
plt.ylabel('Turn Signal')
plt.xlabel('Time (s)')
plt.title('Turn Signal vs Time')
plt.plot(df['TurnSignal'])
plt.show()

# %%
plt.ylabel('VehicleSpeed (mph)')
plt.xlabel('Time (s)')
plt.title('Speed vs Time')
plt.plot(df['VehicleSpeed_mph'])
plt.show()
