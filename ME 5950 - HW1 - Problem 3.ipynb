# %%
import numpy

# %%
import pandas as pd

df = pd.read_excel (r'/Users/oliviakeils/Desktop/Lab0_data.xlsx')

# %%
print(df)
# Out:
#      time_sec  VehicleSpeed_mph  EngineSpeed_rpm  EngineTorque  AccelPedalPos  \
# 0           0         23.838108      2321.373607    181.943925      19.978017
# 1           1         25.183644      1888.784906     63.500000      12.549024
# 2           2         25.592899      1932.336262     46.942052       5.007143
# 3           3         25.483396      1398.949090     -8.576612       0.000000
# 4           4         24.904355      1379.242030    -19.000000       0.000000
# ..        ...               ...              ...           ...            ...
# 826       826         15.377161      2109.273816     63.692830       9.019611
# 827       827         16.387776      1562.750000     38.330566       7.843140
# 828       828         16.879580      1607.067105     38.165314       7.450983
# 829       829         17.458570      1670.917720     71.562284      16.332432
# 830       830         19.819313      2010.301629    134.000000      19.607850
#
# ...

# %%
# Changed the .csv file to a .xlsx file to start the import
# Used the print command to visually show the data was imported properly

# %%
import matplotlib.pyplot as plt

# %%
import pylab as m

# %%
plt.xlabel('Time(s)')
plt.ylabel('Engine Speed (rpm)')
plt.plot(df['time_sec'], df['EngineSpeed_rpm'], label='Engine Speed')
plt.title('Engine Speed vs. Time')
# Out:
# Text(0.5, 1.0, 'Engine Speed vs. Time')

# %%
plt.xlabel('Time(s)')
plt.ylabel('Vehicle Speed (mph)')
plt.plot(df['time_sec'], df['VehicleSpeed_mph'], label='Vehicle Speed')
plt.title('Vehicle Speed vs. Time')
plt.show()

# %%
plt.xlabel('Time(s)')
plt.ylabel('Engine Torque')
plt.plot(df['time_sec'], df['EngineTorque'], label='Engine Torque')
plt.title('Engine Torque vs. Time')
# Out:
# Text(0.5, 1.0, 'Engine Torque vs. Time')

# %%
plt.xlabel('Time(s)')
plt.ylabel('AccelPedalPos (mph)')
plt.plot(df['time_sec'], df['AccelPedalPos'], label='AccelPedalPos')
plt.title('AccelPedalPos vs. Time')
# Out:
# Text(0.5, 1.0, 'AccelPedalPos vs. Time')

# %%
plt.xlabel('Time(s)')
plt.ylabel('BrakePedalPos')
plt.plot(df['time_sec'], df['BrakePedalPos'], label='BrakePedalPos')
plt.title('BrakePedalPos vs. Time')
# Out:
# Text(0.5, 1.0, 'BrakePedalPos vs. Time')

# %%
plt.xlabel('Time(s)')
plt.ylabel('Turn Signal')
plt.plot(df['time_sec'], df['TurnSignal'], label='TurnSignal')
plt.title('TurnSignal vs. Time')
# Out:
# Text(0.5, 1.0, 'TurnSignal vs. Time')

# %%
plt.xlabel('Time(s)')
plt.ylabel('Latitude (deg)')
plt.plot(df['time_sec'], df['Latitude_deg'], label='Latitude (deg)')
plt.title('Latitude vs. Time')
# Out:
# Text(0.5, 1.0, 'Latitude vs. Time')

# %%
plt.xlabel('Time(s)')
plt.ylabel('Longitude (deg)')
plt.plot(df['time_sec'], df['Longitude_deg'], label='Longitude (deg)')
plt.title('Longitude vs. Time')
# Out:
# Text(0.5, 1.0, 'Longitude vs. Time')

# %%
plt.xlabel('Time(s)')
plt.ylabel('Altitude')
plt.plot(df['time_sec'], df['Altitude'], label='Altitude')
plt.title('Altitude vs. Time')
# Out:
# Text(0.5, 1.0, 'Altitude vs. Time')

# %%
plt.xlabel('Time(s)')
plt.ylabel('Distance')
plt.plot(df['time_sec'], df['Distance'], label='Distance')
plt.title('Distance vs. Time')
# Out:
# Text(0.5, 1.0, 'Distance vs. Time')

# %%
plt.xlabel('Time(s)')
plt.ylabel('Steer Angle')
plt.plot(df['time_sec'], df['SteerAngle'], label='Steer Angle')
plt.title('Steer Angle vs. Time')
# Out:
# Text(0.5, 1.0, 'Steer Angle vs. Time')

# %%
plt.xlabel('Time(s)')
plt.ylabel('Transmission Gear')
plt.plot(df['time_sec'], df['TransmissionGear'], label='Transmission Gear')
plt.title('Transmission Gear vs. Time')
# Out:
# Text(0.5, 1.0, 'Transmission Gear vs. Time')

# %%
plt.xlabel('Time(s)')
plt.ylabel('SPaT Signal')
plt.plot(df['time_sec'], df['SPaT_signal'], label='SPaT Signal')
plt.title('SPaT Signal vs. Time')
# Out:
# Text(0.5, 1.0, 'SPaT Signal vs. Time')

# %%
plt.xlabel('Time(s)')
plt.ylabel('SPaT Distance')
plt.plot(df['time_sec'], df['SPaT_dist'], label='SPaT Distance')
plt.title('SPaT Distance vs. Time')
# Out:
# Text(0.5, 1.0, 'SPaT Distance vs. Time')
